# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('C:/Users/arzum/OneDrive/Belgeler/Ada-Lovelace-Academy/exercises/data/birds/birds.csv')

# %%
df.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
df.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_ba12d_row0_col0, #T_ba12d_row0_col1, #T_ba12d_row7_col2, #T_ba12d_row7_col3, #T_ba12d_row7_col4, #T_ba12d_row7_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ba12d_row0_col2, #T_ba12d_row1_col0, #T_ba12d_row1_col3, #T_ba12d_row2_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ba12d_row0_col3, #T_ba12d_row1_col4, #T_ba12d_row2_col0, #T_ba12d_row5_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ba12d_row0_col4 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ba12d_row0_col5 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_ba12d_row1_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_ba12d_row1_col2, #T_ba12d_row5_col1, #T_ba12d_row6_col2, #T_ba12d_row6_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ba12d_row1_col5 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ba12d_row2_col1, #T_ba12d_row6_col3 {
# ...

# %%
# Scatter plot: MinLength ve MaxLength arasındaki ilişki
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MinLength', y='MaxLength', data=df, hue='Category')
plt.title('Scatter Plot: MinLength vs MaxLength')
plt.show()

# %%
sns.boxplot(x='Order', y='MinLength', data=df, palette='Set2')
plt.xticks(rotation=45, ha='right')
plt.title('Box Plot of MinLength by Order')
plt.xticks(rotation='vertical')
plt.show()

# %%
# Koruma Durumuna göre dağılım countplot
plt.figure(figsize=(12, 8))
sns.countplot(x='ConservationStatus', data=df)
plt.title('Conservation Status Distribution ')
plt.show()

# %%
sns.pairplot(df[['MinLength', 'MaxLength', 'MinBodyMass', 'MaxBodyMass']])
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %%
# Z skorlarını hesaplar
z_scores = zscore(df[['MinLength', 'MaxLength', 'MinBodyMass', 'MaxBodyMass', 'MinWingspan', 'MaxWingspan']])

# Her bir değişken için Z skorlarını görselleştir
plt.figure(figsize=(12, 8))
sns.boxplot(data=pd.DataFrame(z_scores, columns=['MinLength', 'MaxLength', 'MinBodyMass', 'MaxBodyMass', 'MinWingspan', 'MaxWingspan']))
plt.title('Box Plot of Z-Scores for Numerical Variables')
plt.show()
